# %%
import numpy as np

# %%
filter1 = np.loadtxt('filter/CaF2_t3mm_transmittance.txt',skiprows=1)
filter2 = np.loadtxt('filter/Coating_Data-PN_FN126-N-1D_ RN_122821A1.csv',skiprows=1, delimiter=',')
filter3 = np.loadtxt('filter/FB130-B-1D_ Coating Run 04252A1.csv', skiprows=1, delimiter=',')
filter4 = np.loadtxt('filter/FN157-N-1D-CQ-120 1100nm-NI-%T.txt')
filter5 = np.loadtxt('filter/SK-1300.csv', delimiter=',')

# %%
import matplotlib.pyplot as plt

plt.plot(filter1[:,0],filter1[:,1]*100,label='CaF2_t3mm')
plt.plot(filter2[:,0],filter2[:,1],label='FN126-N-1D')
plt.plot(filter3[:,0],filter3[:,1],label='FB130-B-1D')
plt.plot(filter4[:,0],filter4[:,1],label='FN157-N-1D')
plt.plot(filter5[:,0],filter5[:,1],label='SK-1300')
plt.xlim(100,200)
plt.ylim(0,100)
plt.legend()
plt.xlabel('wave length [nm]')
plt.ylabel('transmittance [%]')
# Out:
# Text(0, 0.5, 'transmittance [%]')

# %%
filter1[:,0]
# Out:
# array([121. , 121.2, 121.4, 121.6, 121.8, 122. , 122.2, 122.4, 122.6,
#        122.8, 123. , 123.2, 123.4, 123.6, 123.8, 124. , 124.2, 124.4,
#        124.6, 124.8, 125. , 125.2, 125.4, 125.6, 125.8, 126. , 130. ,
#        135. , 140. ])
